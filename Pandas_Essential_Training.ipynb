# %% [markdown]
# ## Python Pandas Essential Training

# %% [markdown]
# #### Chapter 1 Challenges

# %% [markdown]
# List our Olympics Dataframe

# %%
import pandas as pd
olympics = pd.read_csv("C:/Users/Dell/Programming/Trainings_Python/Training_Data/olympics.csv",skiprows=4)
olympics
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# List only the NOC column using both ['..'] and dot notation. what type is this object?

# %%
olympics['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
olympics.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
print(type(olympics['NOC']))
print(type(olympics.NOC))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# List the Edition, City, Athlete Name, and Medal columns. what type is this object

# %%
olympics[['City', 'Athlete', 'Medal']]
# Out:
#           City               Athlete   Medal
# 0       Athens         HAJOS, Alfred    Gold
# 1       Athens      HERSCHMANN, Otto  Silver
# 2       Athens     DRIVAS, Dimitrios  Bronze
# 3       Athens    MALOKINIS, Ioannis    Gold
# 4       Athens    CHASAPIS, Spiridon  Silver
# ...        ...                   ...     ...
# 29211  Beijing        ENGLICH, Mirko  Silver
# 29212  Beijing  MIZGAITIS, Mindaugas  Bronze
# 29213  Beijing       PATRIKEEV, Yuri  Bronze
# 29214  Beijing         LOPEZ, Mijain    Gold
# 29215  Beijing        BAROEV, Khasan  Silver
#
# [29216 rows x 3 columns]

# %% [markdown]
# #### Chapter 2 review

# %%
olympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympics.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# #### Chapter 4 review

# %%
olympics.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
olympics.Gender.value_counts(ascending=True, dropna=False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %%
ath = olympics.Athlete.sort_values()
ath
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
olympics.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# AND = & <br>
# OR = | <br>
# NOT = ~

# %%
olympics['Medal'] == 'Gold'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %%
olympics[olympics['Medal'] == 'Gold']
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
olympics[(olympics['Medal'] == 'Gold') & (olympics['Gender'] == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %%
olympics['Athlete'][olympics['Athlete'].str.contains('Florence')]
# Out:
# 1843                     SYERS, Florence
# 1848                     SYERS, Florence
# 4173                    BARKER, Florence
# 8162          FOULDS-PAUL, June Florence
# 9060          FOULDS-PAUL, June Florence
# 10849    AMOORE-POLLOCK, Judith Florence
# 16817          GRIFFITH-JOYNER, Florence
# 18287          GRIFFITH-JOYNER, Florence
# 18305          GRIFFITH-JOYNER, Florence
# 18347          GRIFFITH-JOYNER, Florence
# 18374          GRIFFITH-JOYNER, Florence
# Name: Athlete, dtype: object

# %% [markdown]
# #### Chapter 4 Challenges

# %% [markdown]
# In which events did Jesse Owens win a medal?

# %%
olympics['Event'][olympics['Athlete'] == 'OWENS, Jesse']
# Out:
# 6427            100m
# 6439            200m
# 6456    4x100m relay
# 6523       long jump
# Name: Event, dtype: object

# %% [markdown]
# Which country has won the most men's gold medals in singles badminton over the years? Sort the results alphabetically by the player's  names.

# %%
df_gmb = olympics[(olympics['Medal'] == 'Gold') & (olympics['Gender'] == 'Men') & (olympics['Sport'] == 'Badminton')]

# %%
df_gmb.sort_values(by= 'Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %% [markdown]
# Which three countries have won the most medals in recent years (from 1984 to 2008)?

# %%
df_recent = olympics[olympics['Edition'] >= 1984]
df_recent['NOC'].value_counts()
# Out:
# USA    1837
# AUS     762
# GER     691
# CHN     679
# RUS     638
#        ...
# ISV       1
# AHO       1
# DJI       1
# SEN       1
# AFG       1
# Name: NOC, Length: 124, dtype: int64

# %% [markdown]
# Display the male gold medal winners for the 100m Track & Field sprint event over the years. List the results starting with the most recent. Show the Olympic City, Edition, Athlete and the country they represent.

# %%
df_gm100 = olympics[(olympics.Gender == 'Men') & (olympics.Medal == 'Gold') & (olympics.Event == '100m')]
df_gm100.sort_values(by= 'Edition', ascending=False)[['City','Edition','Athlete','NOC']]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %% [markdown]
# #### Chapter 4 review

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_1896 = olympics[olympics.Edition == 1896]
df_1896.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df_1896['Sport'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
df_1896['Sport'].value_counts().plot(kind='line');

# %%
df_1896['Sport'].value_counts().plot(kind='bar');

# %%
df_1896['Sport'].value_counts().plot(kind='barh');

# %%
df_1896['Sport'].value_counts().plot(kind='pie');

# %%
plt.figure(facecolor='grey') #or white
df_1896['Sport'].value_counts().plot(kind='pie');

# %%
df_1896['Sport'].value_counts().plot(kind='barh',color='plum');

# %%
df_1896['Sport'].value_counts().plot(kind='line',figsize=(10,3));

# %%
plt.figure(facecolor='white')
df_1896['Sport'].value_counts().plot(kind='pie',colormap = 'Pastel1');

# %% [markdown]
# ### include images from video 27 and 26

# %%
import seaborn as sns

# %% [markdown]
# How many medals have been won by men and women in history of olympics, how many gold, silver and medals were won by each group

# %%
sns.countplot(x= 'Medal', data = olympics)
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
sns.countplot(x= 'Medal', data = olympics, hue= 'Gender')
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %% [markdown]
# ### Chapter 5 challenges

# %% [markdown]
# Plot the number of medals achieved by the Chinese team (men and women) in Beijing 2008 using:
# - matplotlib
# - Seaborn

# %%
df_china2008 = olympics[(olympics.Edition == 2008) & (olympics.NOC == 'CHN')]
df_china2008.head()
# Out:
#           City  Edition     Sport Discipline       Athlete  NOC Gender  \
# 27176  Beijing     2008  Aquatics     Diving   ZHOU, Luxin  CHN    Men
# 27177  Beijing     2008  Aquatics     Diving     WANG, Xin  CHN  Women
# 27178  Beijing     2008  Aquatics     Diving  CHEN, Ruolin  CHN  Women
# 27180  Beijing     2008  Aquatics     Diving      QIN, Kai  CHN    Men
# 27181  Beijing     2008  Aquatics     Diving     HE, Chong  CHN    Men
#
#                 Event Event_gender   Medal
# 27176    10m platform            M  Silver
# 27177    10m platform            W  Bronze
# 27178    10m platform            W    Gold
# 27180  3m springboard            M  Bronze
# 27181  3m springboard            M    Gold

# %%
df_china2008.Gender.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=olympics, x= 'Gender');

# %% [markdown]
# How can you use colormaps to give the data more meaning?

# %%
sns.countplot(data=olympics, x= 'Gender',palette='bwr');

# %% [markdown]
# Plot the number of Gold, Silver and Bronze medals for each gender.

# %%
sns.countplot(x='Medal', data = df_china2008, hue= 'Gender')
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %% [markdown]
# How can you give the data more meaning? Is there anything else you can change to make it more intuitive?

# %%
sns.countplot(x='Medal', data = df_china2008, hue= 'Gender', palette='bwr')
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
sns.countplot(x='Medal', data = df_china2008, hue= 'Gender', palette='bwr',order=['Gold','Silver','Bronze'])
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %% [markdown]
# #### Chapter 4 review

# %%
type(olympics.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
olympics.index[100]
# Out:
# 100

# %%
olympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympics.set_index('Athlete')
# Out:
#                          City  Edition      Sport       Discipline  NOC  \
# Athlete
# HAJOS, Alfred          Athens     1896   Aquatics         Swimming  HUN
# HERSCHMANN, Otto       Athens     1896   Aquatics         Swimming  AUT
# DRIVAS, Dimitrios      Athens     1896   Aquatics         Swimming  GRE
# MALOKINIS, Ioannis     Athens     1896   Aquatics         Swimming  GRE
# CHASAPIS, Spiridon     Athens     1896   Aquatics         Swimming  GRE
# ...                       ...      ...        ...              ...  ...
# ENGLICH, Mirko        Beijing     2008  Wrestling  Wrestling Gre-R  GER
# MIZGAITIS, Mindaugas  Beijing     2008  Wrestling  Wrestling Gre-R  LTU
# PATRIKEEV, Yuri       Beijing     2008  Wrestling  Wrestling Gre-R  ARM
# LOPEZ, Mijain         Beijing     2008  Wrestling  Wrestling Gre-R  CUB
# BAROEV, Khasan        Beijing     2008  Wrestling  Wrestling Gre-R  RUS
#
#                      Gender                       Event Event_gender   Medal
# Athlete
# ...

# %%
olympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympics.set_index('Athlete',inplace=True)

# %%
olympics.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
olympics.reset_index(inplace=True)

# %%
df_ath = olympics.set_index('Athlete')
df_ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
df_ath.reset_index(inplace=True)
df_ath.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df_ath.set_index('Athlete',inplace=True)

# %%
df_ath.sort_index(inplace=True,ascending=False)
df_ath.head()
# Out:
#                        City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
# ÖSTMO, Ole            Paris     1900  Shooting   Shooting  NOR    Men
#
#                                            Event Event_gender   Medal
# Athlete
# ÖSTRAND, Per-Olof                 400m freestyle            M  Bronze
# ÖSTMO, Ole         army rifle, 300m, 3 positions            M  Bronze
# ÖSTMO, Ole                      free rifle, team            M  Silver
# ÖSTMO, Ole            army rifle, 300m, standing            M  Silver
# ÖSTMO, Ole               army rifle, 300m, prone            M  Bronze

# %%
df_ath.reset_index(inplace=True)
df_ath.head()
# Out:
#              Athlete      City  Edition     Sport Discipline  NOC Gender  \
# 0  ÖSTRAND, Per-Olof  Helsinki     1952  Aquatics   Swimming  SWE    Men
# 1         ÖSTMO, Ole     Paris     1900  Shooting   Shooting  NOR    Men
# 2         ÖSTMO, Ole     Paris     1900  Shooting   Shooting  NOR    Men
# 3         ÖSTMO, Ole     Paris     1900  Shooting   Shooting  NOR    Men
# 4         ÖSTMO, Ole     Paris     1900  Shooting   Shooting  NOR    Men
#
#                            Event Event_gender   Medal
# 0                 400m freestyle            M  Bronze
# 1  army rifle, 300m, 3 positions            M  Bronze
# 2               free rifle, team            M  Silver
# 3     army rifle, 300m, standing            M  Silver
# 4        army rifle, 300m, prone            M  Bronze

# %% [markdown]
# .loc[ ] is a label-based indexer for selection by label <br>
# .loc[ ] will raise a key error when the items are not found

# %%
# olympics.loc['BOLT, Usain'] KEY ERROR, The right way:
df_ath = olympics.set_index('Athlete')
df_ath.loc['BOLT, Usain']
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %% [markdown]
# Another way:

# %%
olympics[olympics['Athlete'] == 'BOLT, Usain']
# Out:
#            Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %% [markdown]
# iloc[ ]

# %%
olympics.iloc[1700]
# Out:
# Athlete         RABOT, Pierre
# City                   London
# Edition                  1908
# Sport                 Sailing
# Discipline            Sailing
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# Name: 1700, dtype: object

# %%
olympics.iloc[[1700]]
# Out:
#             Athlete    City  Edition    Sport Discipline  NOC Gender Event  \
# 1700  RABOT, Pierre  London     1908  Sailing    Sailing  FRA    Men    6m
#
#      Event_gender   Medal
# 1700            X  Bronze

# %%
olympics.iloc[[1542,2390,6000,15000]]
# Out:
#                         Athlete         City  Edition       Sport  \
# 1542     DUCKETT, Richard Louis       London     1908    Lacrosse
# 2390         SAASTAMOINEN, Eino    Stockholm     1912  Gymnastics
# 6000            AGOSTONI, Carlo  Los Angeles     1932     Fencing
# 15000  JENSEN, Poul Richard Hoj     Montreal     1976     Sailing
#
#         Discipline  NOC Gender                                    Event  \
# 1542      Lacrosse  CAN    Men                                 lacrosse
# 2390   Artistic G.  FIN    Men                        team, free system
# 6000       Fencing  ITA    Men                          épée individual
# 15000      Sailing  DEN    Men  fleet/match race keelboat open (Soling)
#
#       Event_gender   Medal
# 1542             M    Gold
# 2390             M  Silver
# 6000             M  Bronze
# 15000            X    Gold

# %%
olympics.iloc[1:4]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %% [markdown]
# ### Chapter 6 challenges

# %% [markdown]
# Plot the total number of medals awarded at each of the Olympic games throughout history.

# %%
#Wrong Way:
olympics.groupby('Edition').Medal.value_counts().plot(kind='line',figsize=(10,5),xticks=[],title='Medals Throughout Years');

# %%
olympics.Edition.value_counts().sort_index().plot();

# %% [markdown]
# Which countries did not win a medal in the 2008 Olympics? How many countries were there?

# %%
lo = olympics[olympics.Edition == 2008]
lo.head()
# Out:
#                 Athlete     City  Edition     Sport Discipline  NOC Gender  \
# 27174    GALPERIN, Gleb  Beijing     2008  Aquatics     Diving  RUS    Men
# 27175  MITCHAM, Matthew  Beijing     2008  Aquatics     Diving  AUS    Men
# 27176       ZHOU, Luxin  Beijing     2008  Aquatics     Diving  CHN    Men
# 27177         WANG, Xin  Beijing     2008  Aquatics     Diving  CHN  Women
# 27178      CHEN, Ruolin  Beijing     2008  Aquatics     Diving  CHN  Women
#
#               Event Event_gender   Medal
# 27174  10m platform            M  Bronze
# 27175  10m platform            M    Gold
# 27176  10m platform            M  Silver
# 27177  10m platform            W  Bronze
# 27178  10m platform            W    Gold

# %%
noc = pd.read_csv("C:/Users/Dell/Programming/Trainings_Python/Training_Data/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv")
noc.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
noc[noc['Country'] != noc['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
noc = pd.read_csv("C:/Users/Dell/Programming/Trainings_Python/Training_Data/Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv")
noc.set_index('Int Olympic Committee code', inplace=True)

# %%
noc.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medal_2008 = lo.NOC.value_counts()
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# SUD      1
# EGY      1
# MDA      1
# TOG      1
# MRI      1
# Name: NOC, Length: 86, dtype: int64

# %%
noc['medal_2008'] = medal_2008
noc.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
noc[noc.medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...

# %% [markdown]
# #### Chapter 7 review

# %%
olympics.groupby('Edition')

# %%
type(olympics.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(olympics.groupby('Edition'))
# Out:
# [(1896,
#                         Athlete    City  Edition          Sport  \
#   0               HAJOS, Alfred  Athens     1896       Aquatics
#   1            HERSCHMANN, Otto  Athens     1896       Aquatics
#   2           DRIVAS, Dimitrios  Athens     1896       Aquatics
#   3          MALOKINIS, Ioannis  Athens     1896       Aquatics
#   4          CHASAPIS, Spiridon  Athens     1896       Aquatics
#   ..                        ...     ...      ...            ...
#   146             JENSEN, Viggo  Athens     1896  Weightlifting
#   147       ELLIOTT, Launceston  Athens     1896  Weightlifting
#   148  CHRISTOPOULOS, Stephanos  Athens     1896      Wrestling
#   149            SCHUMANN, Carl  Athens     1896      Wrestling
#   150          TSITAS, Georgios  Athens     1896      Wrestling
#
#             Discipline  NOC Gender                        Event Event_gender  \
#   0           Swimming  HUN    Men               100m freestyle            M
# ...

# %%
for group_key, group_value in olympics.groupby('Edition'):
    print(group_key, 'Group Key')
    print(group_value, 'Group Value')
# Out:
# 1896 Group Key
#                       Athlete    City  Edition          Sport  \
# 0               HAJOS, Alfred  Athens     1896       Aquatics
# 1            HERSCHMANN, Otto  Athens     1896       Aquatics
# 2           DRIVAS, Dimitrios  Athens     1896       Aquatics
# 3          MALOKINIS, Ioannis  Athens     1896       Aquatics
# 4          CHASAPIS, Spiridon  Athens     1896       Aquatics
# ..                        ...     ...      ...            ...
# 146             JENSEN, Viggo  Athens     1896  Weightlifting
# 147       ELLIOTT, Launceston  Athens     1896  Weightlifting
# 148  CHRISTOPOULOS, Stephanos  Athens     1896      Wrestling
# 149            SCHUMANN, Carl  Athens     1896      Wrestling
# 150          TSITAS, Georgios  Athens     1896      Wrestling
#
#           Discipline  NOC Gender                        Event Event_gender  \
# 0           Swimming  HUN    Men               100m freestyle            M
# ...

# %%
type(group_value)
# Out:
# pandas.core.frame.DataFrame

# %%
type(group_key)
# Out:
# int

# %%
olympics.groupby('Edition').size()
#Number of Medals
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
olympics.groupby(['Edition','NOC','Medal']).agg(['min','max','count'])
# Out:
#                                     Athlete                                 \
#                                         min                      max count
# Edition NOC Medal
# 1896    AUS Gold               FLACK, Edwin             FLACK, Edwin     2
#         AUT Bronze            SCHMAL, Adolf            SCHMAL, Adolf     2
#             Gold              NEUMANN, Paul            SCHMAL, Adolf     2
#             Silver         HERSCHMANN, Otto         HERSCHMANN, Otto     1
#         DEN Bronze            JENSEN, Viggo          NIELSEN, Holger     3
# ...                                     ...                      ...   ...
# 2008    UZB Silver        TANGRIEV, Abdullo           TIGIEV, Soslan     2
#         VEN Bronze  CONTRERAS RIVERO, Dalia  CONTRERAS RIVERO, Dalia     1
#         VIE Silver          HOANG, Anh Tuan          HOANG, Anh Tuan     1
#         ZIM Gold           COVENTRY, Kirsty         COVENTRY, Kirsty     1
# ...

# %%
olympics.groupby(['Edition','NOC','Medal']).agg('count')
# Out:
#                     Athlete  City  Sport  Discipline  Gender  Event  \
# Edition NOC Medal
# 1896    AUS Gold          2     2      2           2       2      2
#         AUT Bronze        2     2      2           2       2      2
#             Gold          2     2      2           2       2      2
#             Silver        1     1      1           1       1      1
#         DEN Bronze        3     3      3           3       3      3
# ...                     ...   ...    ...         ...     ...    ...
# 2008    UZB Silver        2     2      2           2       2      2
#         VEN Bronze        1     1      1           1       1      1
#         VIE Silver        1     1      1           1       1      1
#         ZIM Gold          1     1      1           1       1      1
#             Silver        3     3      3           3       3      3
#
#                     Event_gender
# Edition NOC Medal
# 1896    AUS Gold               2
#         AUT Bronze             2
# ...

# %%
olympics.groupby(['Edition','NOC','Medal']).agg({'Edition': ['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
olympics.loc[olympics.Athlete == 'LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
olympics.loc[olympics.Athlete == 'LEWIS, Carl'].groupby('Athlete').agg(['min','max','count'])
# Out:
#                 City              Edition                  Sport             \
#                  min    max count     min   max count        min        max
# Athlete
# LEWIS, Carl  Atlanta  Seoul    10    1984  1996    10  Athletics  Athletics
#
#                   Discipline  ... Gender Event                  Event_gender  \
#             count        min  ...  count   min        max count          min
# Athlete                       ...
# LEWIS, Carl    10  Athletics  ...     10  100m  long jump    10            M
#
#                       Medal
#             max count   min     max count
# Athlete
# LEWIS, Carl   M    10  Gold  Silver    10
#
# [1 rows x 27 columns]

# %% [markdown]
# Using groupby(), plot the total number of medals awarded at each of the Olympic games throughout history.

# %%
olympics.groupby('Edition').agg('count')['Medal'].plot()
# Out:
# <AxesSubplot:xlabel='Edition'>

# %%
#Another Way
olympics.groupby('Edition').size().plot

# %% [markdown]
# Create a list showing the total number of medals won for each country over the history of the Olympics. For each country, include the year of the first and most recent Olympic medal wins.

# %%
olympics.groupby('NOC').agg(['count','min','max'])
# Out:
#     Athlete                                                  City             \
#       count                     min                     max count        min
# NOC
# AFG       1        NIKPAI, Rohullah        NIKPAI, Rohullah     1    Beijing
# AHO       1         BOERSMA, Jan D.         BOERSMA, Jan D.     1      Seoul
# ALG      14        ALLALOU, Mohamed          ZAOUI, Mohamed    14    Atlanta
# ANZ      29      BAKER, Reginald L.       WYLIE, Wilhelmina    29     London
# ARG     239         ACOSTA, Lautaro          ZUMELZU, A. B.   239  Amsterdam
# ..      ...                     ...                     ...   ...        ...
# VIE       2         HOANG, Anh Tuan         TRAN, Hieu Ngan     2    Beijing
# YUG     435  ANASTASOVSKI, Svetlana           ZUZEJ, Marjan   435  Amsterdam
# ZAM       2          MATETE, Samuel            MWILA, Keith     2    Atlanta
# ZIM      23  BOXHALL, Arlene Nadine  WATSON, Linda Margaret    23     Athens
# ...

# %%
olympics.groupby('NOC').agg({'Edition':['count','min','max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %% [markdown]
# ### Chapter 8 review

# %% [markdown]
# Athletes winning medals in Beijing Olympics 100m or 200m track event

# %%
mw = olympics[(olympics.Edition == 2008) & ((olympics.Event == '100m') | (olympics.Event == '200m'))]
mw
# Out:
#                         Athlete     City  Edition      Sport Discipline  NOC  \
# 27551               DIX, Walter  Beijing     2008  Athletics  Athletics  USA
# 27552               BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM
# 27553         THOMPSON, Richard  Beijing     2008  Athletics  Athletics  TRI
# 27554        FRASER, Shelly-ann  Beijing     2008  Athletics  Athletics  JAM
# 27555          SIMPSON, Sherone  Beijing     2008  Athletics  Athletics  JAM
# 27556           STEWART, Kerron  Beijing     2008  Athletics  Athletics  JAM
# 27569               DIX, Walter  Beijing     2008  Athletics  Athletics  USA
# 27570               BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM
# 27571           CRAWFORD, Shawn  Beijing     2008  Athletics  Athletics  USA
# 27572           STEWART, Kerron  Beijing     2008  Athletics  Athletics  JAM
# 27573  CAMPBELL-BROWN, Veronica  Beijing     2008  Athletics  Athletics  JAM
# ...

# %%
g = mw.groupby(['NOC','Gender','Discipline','Event']).size()
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
df_unst = g.unstack(['Discipline','Event'])
df_unst
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
df_unst.stack()
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %%
df_unst.stack('Event')
# Out:
# Discipline        Athletics
# NOC Gender Event
# JAM Men    100m         1.0
#            200m         1.0
#     Women  100m         3.0
#            200m         2.0
# TRI Men    100m         1.0
# USA Men    100m         1.0
#            200m         2.0
#     Women  200m         1.0

# %% [markdown]
# Rule of thumb: stack makes a dataframe taller

# %%
df_unst
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
df_unst.unstack()
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
df_unst.unstack('Gender')
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %% [markdown]
# ### Chapter 8 Challenges

# %% [markdown]
# Plot the number of gold medals won by the USA male and female athletes throughout the history of the Olympics?

# %%
from matplotlib.pyplot import fill


df_usag = olympics[(olympics.Medal == 'Gold') & (olympics.NOC == 'USA')]#[['Edition','Gender','NOC','Medal']]
df_usag.groupby(['Edition','Gender']).size().unstack('Gender',fill_value=0)
# Out:
# Gender   Men  Women
# Edition
# 1896      11      0
# 1900      26      1
# 1904     140      6
# 1908      34      0
# 1912      45      0
# 1920     103      7
# 1924      95     15
# 1928      34      9
# 1932      61     17
# 1936      44      7
# 1948      75      8
# 1952      72      7
# 1956      57      4
# 1960      51     17
# 1964      63     15
# 1968      59     24
# 1972      37     16
# 1976      56      7
# 1984     106     62
# 1988      49     28
# 1992      57     32
# 1996      59    101
# 2000      68     62
# 2004      51     65
# 2008      67     58

# %%
df_usag.groupby(['Edition','Gender']).size().unstack('Gender',fill_value=0).plot()
# Out:
# <AxesSubplot:xlabel='Edition'>

# %% [markdown]
# Plot the 5 athletes who have won the most gold medals over the history of the Olympics. When there is a tie, consider the number of silver medals, then bronze medals.

# %%
df_gold = olympics.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
df_gold
# Out:
# Medal                      Bronze  Gold  Silver
# Athlete
# AABYE, Edgar                    0     1       0
# AALTONEN, Arvo Ossian           2     0       0
# AALTONEN, Paavo Johannes        2     3       0
# AAMODT, Ragnhild                0     1       0
# AANING, Alf Lied                0     0       1
# ...                           ...   ...     ...
# ÖSTERVOLD, Jan Olsen            0     1       0
# ÖSTERVOLD, Kristian Olsen       0     1       0
# ÖSTERVOLD, Ole Olsen            0     1       0
# ÖSTMO, Ole                      2     0       2
# ÖSTRAND, Per-Olof               1     0       0
#
# [21413 rows x 3 columns]

# %%
df_gold.sort_values(['Gold','Silver','Bronze'], ascending=False)
# Out:
# Medal                Bronze  Gold  Silver
# Athlete
# PHELPS, Michael           2    14       0
# LATYNINA, Larisa          4     9       5
# NURMI, Paavo              0     9       3
# SPITZ, Mark               1     9       1
# LEWIS, Carl               0     9       1
# ...                     ...   ...     ...
# ZYCH, Boguslaw            1     0       0
# ZÄHRINGER, Klaus          1     0       0
# ZÜHLKE, Steffen           1     0       0
# ÖRSTED, Hans-Henrik       1     0       0
# ÖSTRAND, Per-Olof         1     0       0
#
# [21413 rows x 3 columns]

# %%
df_gold.sort_values(['Gold','Silver','Bronze'], ascending=False)[['Gold','Silver','Bronze']]
# Out:
# Medal                Gold  Silver  Bronze
# Athlete
# PHELPS, Michael        14       0       2
# LATYNINA, Larisa        9       5       4
# NURMI, Paavo            9       3       0
# SPITZ, Mark             9       1       1
# LEWIS, Carl             9       1       0
# ...                   ...     ...     ...
# ZYCH, Boguslaw          0       0       1
# ZÄHRINGER, Klaus        0       0       1
# ZÜHLKE, Steffen         0       0       1
# ÖRSTED, Hans-Henrik     0       0       1
# ÖSTRAND, Per-Olof       0       0       1
#
# [21413 rows x 3 columns]

# %%
df_gold.sort_values(['Gold','Silver','Bronze'], ascending=False)[['Gold','Silver','Bronze']].head().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %% [markdown]
# ### Chapter 8 Challenges

# %% [markdown]
# Using the Olympic dataset, present a summary of the total medals won by participating countries in the 2008 Olympics

# %%
df_2008 = olympics[olympics.Edition == 2008]
df_2008.head()
# Out:
#                 Athlete     City  Edition     Sport Discipline  NOC Gender  \
# 27174    GALPERIN, Gleb  Beijing     2008  Aquatics     Diving  RUS    Men
# 27175  MITCHAM, Matthew  Beijing     2008  Aquatics     Diving  AUS    Men
# 27176       ZHOU, Luxin  Beijing     2008  Aquatics     Diving  CHN    Men
# 27177         WANG, Xin  Beijing     2008  Aquatics     Diving  CHN  Women
# 27178      CHEN, Ruolin  Beijing     2008  Aquatics     Diving  CHN  Women
#
#               Event Event_gender   Medal
# 27174  10m platform            M  Bronze
# 27175  10m platform            M    Gold
# 27176  10m platform            M  Silver
# 27177  10m platform            W  Bronze
# 27178  10m platform            W    Gold

# %%
df_2008.groupby(['NOC','Medal']).size()
# Out:
# NOC  Medal
# AFG  Bronze     1
# ALG  Bronze     1
#      Silver     1
# ARG  Bronze    31
#      Gold      20
#                ..
# UZB  Silver     2
# VEN  Bronze     1
# VIE  Silver     1
# ZIM  Gold       1
#      Silver     3
# Length: 188, dtype: int64

# %%
df_2008_sorted = df_2008.groupby(['NOC','Medal']).size().unstack('Medal',fill_value=0)
df_2008_sorted
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# AFG         1     0       0
# ALG         1     0       1
# ARG        31    20       0
# ARM         6     0       0
# AUS        76    31      42
# ..        ...   ...     ...
# USA        81   125     109
# UZB         3     1       2
# VEN         1     0       0
# VIE         0     0       1
# ZIM         0     1       3
#
# [86 rows x 3 columns]

# %%
df_2008_sorted = df_2008_sorted.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']]
df_2008_sorted
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
sns.heatmap(data=df_2008_sorted)
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='NOC'>

# %%
df_2008_sorted_T = df_2008_sorted.transpose()
df_2008_sorted_T
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN  ...  VIE  ARM  TPE  \
# Medal                                                     ...
# Gold    125   74   43   42   41   40   31   31   25   23  ...    0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11  ...    1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17  ...    0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
plt.figure(figsize=(16,5))
sns.heatmap(df_2008_sorted_T,cmap='cool')
# Out:
# <AxesSubplot:xlabel='NOC', ylabel='Medal'>

# %% [markdown]
# Create your own colormaps

# %% [markdown]
# Plot the 5 athletes who have won the most gold medals over the history of the Olympics. When there is a tie, consider the number of silver medals, then bronze medals.

# %%
df_gold = olympics.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
df_gold.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
from matplotlib.colors import ListedColormap

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette(sns.color_palette())
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
gsb = ['#dbb40c','#c5c9c7','#a87900']
sns.palplot(gsb)
my_gsb = ListedColormap(sns.color_palette(gsb))

# %%
df_gold = olympics.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)
df_gold_head = df_gold.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head()
df_gold_head.plot(kind='bar',colormap=my_gsb)
# Out:
# <AxesSubplot:xlabel='Athlete'>
